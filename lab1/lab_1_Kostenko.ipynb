# %%
# Лабораторна робота №1. Інсталяція та налаштування Python-середовища

# %%
# Мета: quick start для роботи з python3 у середовищі IDE PyCharm системою контроля версій git.

# %%
# Author: Nikita Kostenko

# %%
# Контрольні запитання:
# 1.)У чому відмінність інтерпретатора від компілятора? Python – компілятор чи інтерпретатор? 
# Компілятор після роботи дає вихідний файл який містить машиний код і який можно запустити без додаткових засобів.
# Інтерпретатор - не дає вихідний файл а відразу запускає код і перекладає його в машиний код і для запуску цієї програми потрібно встановити як мінімум мову програмування на якій написаний цей код.

# 2.)Що таке IDE PyCharm?
# Продвинутий редактор коду який дозволяє писати код значно швидше та якісніше

# 3.)Що таке система контроля версій (СКВ) і для чого вона призначена? У чому принципова відмінність СКВ SVN та GIT?
# Система контролю версій це система яка допомогає розробникам одночасно розробляти один проект та в разі потреби(наприклад треба откатити програму до минулої версії) отримати код минулої версії програми.

# 4.)Що відбувається при виконанні команди git add .?
# Файли додаються в індекс щоб вони могли в подальшому збережені в локальному репозиторію

# 5.)Що відбувається при виконанні команди git commit?
# Файли додаються до локального репозиторію

# 6.)Якою Git-командою виконується розміщення локальної копії Git-репозиторію проєкта на віддаленому, що знаходиться на GitHub?
# Головний репозиторій проекту.
